# %% [markdown]
# <a href="https://colab.research.google.com/github/sourabhprk31/sourabhprk31.github.io/blob/main/NLP_without_AWS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 2.7 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.5 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 46.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 52.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 37.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.11.6 transformers-4.17.0

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
tokenizer = AutoTokenizer.from_pretrained("prk/roberta-base-squad2-finetuned-squad")
model = AutoModelForQuestionAnswering.from_pretrained("prk/roberta-base-squad2-finetuned-squad")
# Out:
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/777 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/473M [00:00<?, ?B/s]

# %%
# !unzip -q com.zip -d ../new

# %%
from transformers import pipeline
nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)

# %%
question, context = "Who is Sourabh Prakash?", "Sourabh Prakash is an HCL employee."
res = nlp({
    'question': question,
    'context': context
})

# %%
res['answer']
# Out:
# 'an HCL employee'

# %%
questionDictioary = {}
questiondictionatyGlobalcount = 0

    #xls = ExcelFile(r"c:\2022\requirements1.xls")
    #data = xls.parse(xls.sheet_names[0])
   # wrkbk = openpyxl.load_workbook(r"c:\2022\requirements1.xlsx")
exceldata = {}
   # sh = wrkbk.active
    #print(data.to_dict())

def dict1(sample_dict, key, list_of_values):
        if key not in sample_dict and key != "None":
            sample_dict[key] = list_of_values
        #sample_dict[key].extend(list_of_values)
        return sample_dict

# %%
import openpyxl
from string import punctuation
from nltk.corpus import stopwords

# %%
def copytoExcel(filename , row , column , value):

        wrkbk = openpyxl.load_workbook(filename)
        exceldata = {}
        sh = wrkbk.active
        c1 = sh.cell(row=row, column=column)

        # writing values to cells
        c1.value =  value

       # c2 = sheet.cell(row=1, column=2)
       # c2.value = "RAI"
        wrkbk.save( filename)
        wrkbk.close()

def ReadfromExcel(filename):

    # load excel with its path
        wrkbk = openpyxl.load_workbook(filename)
        exceldata = {}
        sh = wrkbk.active
        appendtext = ''
        # iterate through excel and display data
        for i in range(1, sh.max_row+1):
          #  print("\n")
           # print("Row ", i, " data :")
            appendtext = ''
            for j in range(1, sh.max_column + 1):
                cell_obj = sh.cell(row=i, column=j)
              #  exceldata[i].append(cell_obj.value)
                #if(cell_obj.value )
                appendtext = appendtext + str(cell_obj.value) + ";"

                #print(appendtext)
            dict1(exceldata, i, appendtext)
        wrkbk.close();

        return exceldata


def clean_doc(doc):
        # split into tokens by white space
        tokens = doc.split()
        # remove punctuation from each token
        table = str.maketrans('', '', punctuation)
        tokens = [w.translate(table) for w in tokens]
        # remove remaining tokens that are not alphabetic
        tokens = [word for word in tokens if word.isalpha()]
        # filter out stop words
        stop_words = set(stopwords.words('english'))
        tokens = [w for w in tokens if not w in stop_words]
        # filter out short tokens
        tokens = [word for word in tokens if len(word) > 1]
        return tokens

def removeBrackets(str):
    str = str.replace('(','')
    str = str.replace(')','')
    # str = str.replace('=',',')
    print(str)
    return str

def splitString(str):
	splittedString = str.split('=')
	for i in range(len(splittedString)):
		splittedString[i] = splittedString[i].strip()
	# print(splittedString)
	return splittedString

def Ques1Ans(str1, str2):
    str1 = str1.replace("QAns1" , str2)
    return str1

# exceldata1 = ReadfromExcel(r"final3.xlsx")
ContextAndQuestionmap = {}

# %%
exceldata1 = ReadfromExcel(r"../new/compressed/final2.xlsx")

# %%
for i in exceldata1 :
        print(i, exceldata1[i])
        if (i > 1 ):
           text = exceldata1[i]
           textcontext = text.split(";")
        #    print ("first value")
        #    print(textcontext[1])
           questionAns = textcontext[3].split(",")
           for j in range(0, len(questionAns)):
               list1 = [questionAns[j], textcontext[1]]
               questionDictioary[questiondictionatyGlobalcount] = list1
              # ContextAndQuestionmap[questiondictionatyGlobalcount] = len(questionAns)
               questiondictionatyGlobalcount = questiondictionatyGlobalcount + 1
# Out:
# 1 ID;Requirement;None;Questions;None;None;None;None;None;None;
# 2 AFCU_SREQ_7245;The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:
# C1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.
# C2: (VI_Air_Ground_Status = GROUND);1;what shall be set?, What is C1?, what is C2?;None;None;None;None;None;None;
# 3 AFCU_SREQ_6102​;The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR
# C2: (Air_Ground_2 = IN AIR));1;what shall be set?, What is C1?, what is C2?;None;None;None;None;None;None;
# 4 AFCU_SREQ_6177;The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED) ;2;what shall be set?, What is C1?, what is C2?, what is  C3?;None;None;None;None;None;None;
# 5 AFCU_SREQ_6178;The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED) ;2;what shall be set?, What is C1?, what is C2?, what is  C3?;None;None;None;None;None;None;
# 6 AFCU_SREQ_6740​;The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY));3;what shall be set?, What is C1?, what is C2?, what is  C3?, what is C4?;None;None;None;None;None;None;
# 7 AFCU_SREQ_8337​;The Operational Software in microcontroller B shall set
# C1: HB_Mon_B = HIGH, If HB_Mon_A = LOW
# C2: HB_Mon_B = LOW, If HB_Mon_A = HIGH;1;what shall be set?, What is C1?, what is C2?;None;None;None;None;None;None;
# 8 AFCU_SREQ_6743​;The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND
# C1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR
# C2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))
# else set to
# C3: FD_CTFS_Stop_Mismatch = FALSE;2;what shall be set?, What is C1?, what is C2?, what is  C3?;None;None;None;None;None;None;
# 9 AFCU_SREQ_6750​;The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET));3;what shall be set?, What is C1?, what is C2?, what is  C3?, what is C4?;None;None;None;None;None;None;
# 10 AFCU_SREQ_6740​;The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY));3;what shall be set?, What is C1?, what is C2?, what is  C3?, what is C4?;None;None;None;None;None;None;

# %%
newline = '\n'
bold = '\033[1m'
unbold = '\033[0m'
ansvalue =""
ansvalue1 =""
ansvalue2 = ""
AnsDictionary = {}
AnsDictionary2 = {}
count =  2
previousContext = ""
QDnew = {}
predictionAnswerList = []
flag = 1
tempList = ["" , "=" , "NoAnswer"]
for K in questionDictioary:
        # if K>0:
        #     questionDictioary[K][0] = Ques1Ans(questionDictioary[K][0] , predictionAnswerList[K-1])
        question_context = questionDictioary[K]
        print("data inside for loop")
        print (question_context)
        # QDnew['question'] = questionDictioary[K][0]
        # QDnew['context'] = questionDictioary[K][1]
        question = questionDictioary[K][0]
        context = questionDictioary[K][1]
        ##question_context = QDnew
        model_predictions = nlp({'question': question, 'context': context})
        print ("model Predictions")
        print (model_predictions)
        model_predictions = model_predictions['answer']
        if( model_predictions.isdigit()):
            model_predictionsstr = removeBrackets(model_predictions)
            if (flag == 1):
                model_predictionsstr_list = splitString(model_predictionsstr)
                length = len(model_predictionsstr_list)
                print(length)
                newString = ""
                for t in range(0,length-1):
                    newString += model_predictionsstr_list[t] + ","
                newString += model_predictionsstr_list[length-1]
                model_predictionsstr = newString
            
        else :
            #model_predictions = clean_doc(model_predictions)
            model_predictionsstr = removeBrackets(model_predictions)
            if (flag == 1):
                model_predictionsstr_list = splitString(model_predictionsstr)
                length = len(model_predictionsstr_list)
                print(length)
                newString = ""
                for t in range(0,length-1):
                    newString += model_predictionsstr_list[t] + ","
                newString += model_predictionsstr_list[length-1]
                model_predictionsstr = newString

        predictionAnswerList.append(model_predictionsstr)

        if ( K == 0):
            previousContext = question_context[1]
        if(  previousContext == question_context[1]):
            # flag = 0
            if (ansvalue != ""):
                ansvalue = str(ansvalue) + "," + str(model_predictionsstr)
                ansvalue2 = str(ansvalue2) + "," + str(model_predictions)
            else:
                ansvalue = str(model_predictionsstr)
                ansvalue2 = str(model_predictions)
        else :
            # flag = 1
            AnsDictionary[count] = ansvalue
            AnsDictionary2[count] = ansvalue2
            count = count + 1
            ansvalue = "";
            if (ansvalue != ""):
                ansvalue = str(ansvalue) + "," + str(model_predictionsstr)
                ansvalue2 = str(ansvalue2) + "," + str(model_predictions)
            else:
                ansvalue = str(model_predictionsstr)
                ansvalue2 = str(model_predictions)

                """
        if(count < 3) :
            if(ansvalue != ""):
                ansvalue = str(ansvalue) +","+  str(model_predictionsstr)
            else:
                ansvalue = str(model_predictionsstr)
        else:
            if (ansvalue1 != ""):
                ansvalue1 = str(ansvalue1) + "," + str(model_predictionsstr)
            else:
                ansvalue1 = str(model_predictionsstr)
        count = count + 1
        """
        print (f"Inference:{newline}"
                f"Question: {bold}{question_context[0]}{unbold}{newline}"
                f"Context: {question_context[1]}{newline}"
                f"model answer: {bold}{model_predictionsstr}{unbold}{newline}")
        previousContext = question_context[1]
       # AnsDictionary[k] =
AnsDictionary[count] = ansvalue
AnsDictionary2[count] = ansvalue2
print(count)
# print("answer Value")
# print(AnsDictionary[2])
# print("answer Value")
# print(AnsDictionary[3])
# copytoExcel(r"final32.xlsx", 2, 5 ,AnsDictionary[2])
# copytoExcel(r"final32.xlsx", 3, 5, AnsDictionary[3])
# print(predictionAnswerList)
# Out:
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:\nC1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.\nC2: (VI_Air_Ground_Status = GROUND)']
# model Predictions
# {'score': 0.9033588767051697, 'start': 35, 'end': 65, 'answer': 'VI_Delayed_In_Air = NOT IN AIR'}
# VI_Delayed_In_Air = NOT IN AIR
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:
# C1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.
# C2: (VI_Air_Ground_Status = GROUND)
# model answer: VI_Delayed_In_Air,NOT IN AIR
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:\nC1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.\nC2: (VI_Air_Ground_Status = GROUND)']
# model Predictions
# {'score': 0.6105570793151855, 'start': 118, 'end': 144, 'answer': 'VI_Air_Ground_Status = AIR'}
# VI_Air_Ground_Status = AIR
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:
# C1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.
# C2: (VI_Air_Ground_Status = GROUND)
# model answer: VI_Air_Ground_Status,AIR
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:\nC1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.\nC2: (VI_Air_Ground_Status = GROUND)']
# model Predictions
# {'score': 0.9465562105178833, 'start': 198, 'end': 227, 'answer': 'VI_Air_Ground_Status = GROUND'}
# VI_Air_Ground_Status = GROUND
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:
# C1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.
# C2: (VI_Air_Ground_Status = GROUND)
# model answer: VI_Air_Ground_Status,GROUND
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR \nC2: (Air_Ground_2 = IN AIR))']
# model Predictions
# {'score': 0.8049453496932983, 'start': 35, 'end': 61, 'answer': 'VI_Air_Ground_Status = AIR'}
# VI_Air_Ground_Status = AIR
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR
# C2: (Air_Ground_2 = IN AIR))
# model answer: VI_Air_Ground_Status,AIR
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR \nC2: (Air_Ground_2 = IN AIR))']
# model Predictions
# {'score': 0.9411266446113586, 'start': 72, 'end': 100, 'answer': 'Air_Ground_1 = NOT ON GROUND'}
# Air_Ground_1 = NOT ON GROUND
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR
# C2: (Air_Ground_2 = IN AIR))
# model answer: Air_Ground_1,NOT ON GROUND
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR \nC2: (Air_Ground_2 = IN AIR))']
# model Predictions
# {'score': 0.9626983404159546, 'start': 111, 'end': 132, 'answer': 'Air_Ground_2 = IN AIR'}
# Air_Ground_2 = IN AIR
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR
# C2: (Air_Ground_2 = IN AIR))
# model answer: Air_Ground_2,IN AIR
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)']
# model Predictions
# {'score': 0.013396582566201687, 'start': 35, 'end': 71, 'answer': 'Bleed_Air_Valve_Enable_Cmd = ENABLED'}
# Bleed_Air_Valve_Enable_Cmd = ENABLED
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)
# model answer: Bleed_Air_Valve_Enable_Cmd,ENABLED
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)']
# model Predictions
# {'score': 0.9360862374305725, 'start': 121, 'end': 145, 'answer': 'AFCU_State = MAINTENANCE'}
# AFCU_State = MAINTENANCE
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)
# model answer: AFCU_State,MAINTENANCE
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)']
# model Predictions
# {'score': 0.9363442063331604, 'start': 152, 'end': 191, 'answer': 'Bleed_Air_Valve_Cmd_Override = OVERRIDE'}
# Bleed_Air_Valve_Cmd_Override = OVERRIDE
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)
# model answer: Bleed_Air_Valve_Cmd_Override,OVERRIDE
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)']
# model Predictions
# {'score': 0.0022012528497725725, 'start': 199, 'end': 232, 'answer': 'Maint_Bleed_Air_Valve_Enabled_Cmd'}
# Maint_Bleed_Air_Valve_Enabled_Cmd
# 1
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)
# model answer: Maint_Bleed_Air_Valve_Enabled_Cmd
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)']
# model Predictions
# {'score': 0.9461983442306519, 'start': 35, 'end': 72, 'answer': 'Bleed_Air_Valve_Enable_Cmd = DISABLED'}
# Bleed_Air_Valve_Enable_Cmd = DISABLED
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)
# model answer: Bleed_Air_Valve_Enable_Cmd,DISABLED
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)']
# model Predictions
# {'score': 0.9399346113204956, 'start': 122, 'end': 146, 'answer': 'AFCU_State = MAINTENANCE'}
# AFCU_State = MAINTENANCE
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)
# model answer: AFCU_State,MAINTENANCE
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)']
# model Predictions
# {'score': 0.941767692565918, 'start': 153, 'end': 192, 'answer': 'Bleed_Air_Valve_Cmd_Override = OVERRIDE'}
# Bleed_Air_Valve_Cmd_Override = OVERRIDE
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)
# model answer: Bleed_Air_Valve_Cmd_Override,OVERRIDE
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)']
# model Predictions
# {'score': 0.004228455480188131, 'start': 200, 'end': 233, 'answer': 'Maint_Bleed_Air_Valve_Enabled_Cmd'}
# Maint_Bleed_Air_Valve_Enabled_Cmd
# 1
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)
# model answer: Maint_Bleed_Air_Valve_Enabled_Cmd
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9531180262565613, 'start': 35, 'end': 58, 'answer': 'FD_LLFS_Rev_Snsr = TRUE'}
# FD_LLFS_Rev_Snsr = TRUE
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: FD_LLFS_Rev_Snsr,TRUE
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9402456879615784, 'start': 69, 'end': 99, 'answer': 'Upper_Level_Float_Switch = WET'}
# Upper_Level_Float_Switch = WET
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Upper_Level_Float_Switch,WET
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9362202286720276, 'start': 111, 'end': 141, 'answer': 'Low_Level_Float_Switch_1 = DRY'}
# Low_Level_Float_Switch_1 = DRY
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Low_Level_Float_Switch_1,DRY
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.953607976436615, 'start': 153, 'end': 183, 'answer': 'Upper_Level_Float_Switch = WET'}
# Upper_Level_Float_Switch = WET
# 2
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Upper_Level_Float_Switch,WET
#
# data inside for loop
# [' what is C4?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9471179246902466, 'start': 195, 'end': 225, 'answer': 'Low_Level_Float_Switch_2 = DRY'}
# Low_Level_Float_Switch_2 = DRY
# 2
# Inference:
# Question:  what is C4?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Low_Level_Float_Switch_2,DRY
#
# data inside for loop
# ['what shall be set?', 'The Operational Software in microcontroller B shall set \nC1: HB_Mon_B = HIGH, If HB_Mon_A = LOW\nC2: HB_Mon_B = LOW, If HB_Mon_A = HIGH']
# model Predictions
# {'score': 0.4042980372905731, 'start': 61, 'end': 76, 'answer': 'HB_Mon_B = HIGH'}
# HB_Mon_B = HIGH
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software in microcontroller B shall set
# C1: HB_Mon_B = HIGH, If HB_Mon_A = LOW
# C2: HB_Mon_B = LOW, If HB_Mon_A = HIGH
# model answer: HB_Mon_B,HIGH
#
# data inside for loop
# [' What is C1?', 'The Operational Software in microcontroller B shall set \nC1: HB_Mon_B = HIGH, If HB_Mon_A = LOW\nC2: HB_Mon_B = LOW, If HB_Mon_A = HIGH']
# model Predictions
# {'score': 0.9022924900054932, 'start': 61, 'end': 76, 'answer': 'HB_Mon_B = HIGH'}
# HB_Mon_B = HIGH
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software in microcontroller B shall set
# C1: HB_Mon_B = HIGH, If HB_Mon_A = LOW
# C2: HB_Mon_B = LOW, If HB_Mon_A = HIGH
# model answer: HB_Mon_B,HIGH
#
# data inside for loop
# [' what is C2?', 'The Operational Software in microcontroller B shall set \nC1: HB_Mon_B = HIGH, If HB_Mon_A = LOW\nC2: HB_Mon_B = LOW, If HB_Mon_A = HIGH']
# model Predictions
# {'score': 0.9788903594017029, 'start': 100, 'end': 114, 'answer': 'HB_Mon_B = LOW'}
# HB_Mon_B = LOW
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software in microcontroller B shall set
# C1: HB_Mon_B = HIGH, If HB_Mon_A = LOW
# C2: HB_Mon_B = LOW, If HB_Mon_A = HIGH
# model answer: HB_Mon_B,LOW
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND\nC1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR\nC2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))\nelse set to \nC3: FD_CTFS_Stop_Mismatch = FALSE']
# model Predictions
# {'score': 0.9289619326591492, 'start': 35, 'end': 63, 'answer': 'FD_CTFS_Stop_Mismatch = TRUE'}
# FD_CTFS_Stop_Mismatch = TRUE
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND
# C1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR
# C2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))
# else set to
# C3: FD_CTFS_Stop_Mismatch = FALSE
# model answer: FD_CTFS_Stop_Mismatch,TRUE
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND\nC1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR\nC2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))\nelse set to \nC3: FD_CTFS_Stop_Mismatch = FALSE']
# model Predictions
# {'score': 0.5583967566490173, 'start': 105, 'end': 122, 'answer': 'CTFS_Stop_A = DRY'}
# CTFS_Stop_A = DRY
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND
# C1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR
# C2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))
# else set to
# C3: FD_CTFS_Stop_Mismatch = FALSE
# model answer: CTFS_Stop_A,DRY
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND\nC1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR\nC2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))\nelse set to \nC3: FD_CTFS_Stop_Mismatch = FALSE']
# model Predictions
# {'score': 0.6339369416236877, 'start': 158, 'end': 175, 'answer': 'CTFS_Stop_A = WET'}
# CTFS_Stop_A = WET
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND
# C1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR
# C2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))
# else set to
# C3: FD_CTFS_Stop_Mismatch = FALSE
# model answer: CTFS_Stop_A,WET
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND\nC1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR\nC2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))\nelse set to \nC3: FD_CTFS_Stop_Mismatch = FALSE']
# model Predictions
# {'score': 0.9842002391815186, 'start': 219, 'end': 248, 'answer': 'FD_CTFS_Stop_Mismatch = FALSE'}
# FD_CTFS_Stop_Mismatch = FALSE
# 2
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND
# C1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR
# C2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))
# else set to
# C3: FD_CTFS_Stop_Mismatch = FALSE
# model answer: FD_CTFS_Stop_Mismatch,FALSE
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))']
# model Predictions
# {'score': 0.9692360162734985, 'start': 35, 'end': 61, 'answer': 'FD_CTFS_Rev_Snsr_X = FALSE'}
# FD_CTFS_Rev_Snsr_X = FALSE
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))
# model answer: FD_CTFS_Rev_Snsr_X,FALSE
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))']
# model Predictions
# {'score': 0.9555261731147766, 'start': 72, 'end': 89, 'answer': 'CTFS_Stop_X = DRY'}
# CTFS_Stop_X = DRY
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))
# model answer: CTFS_Stop_X,DRY
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))']
# model Predictions
# {'score': 0.7916728258132935, 'start': 100, 'end': 117, 'answer': 'CTFS_Stop_X = WET'}
# CTFS_Stop_X = WET
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))
# model answer: CTFS_Stop_X,WET
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))']
# model Predictions
# {'score': 8.201487617043313e-06, 'start': 100, 'end': 117, 'answer': 'CTFS_Stop_X = WET'}
# CTFS_Stop_X = WET
# 2
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))
# model answer: CTFS_Stop_X,WET
#
# data inside for loop
# [' what is C4?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))']
# model Predictions
# {'score': 3.4052816317853285e-06, 'start': 100, 'end': 117, 'answer': 'CTFS_Stop_X = WET'}
# CTFS_Stop_X = WET
# 2
# Inference:
# Question:  what is C4?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET)))
# model answer: CTFS_Stop_X,WET
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9531180262565613, 'start': 35, 'end': 58, 'answer': 'FD_LLFS_Rev_Snsr = TRUE'}
# FD_LLFS_Rev_Snsr = TRUE
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: FD_LLFS_Rev_Snsr,TRUE
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9402456879615784, 'start': 69, 'end': 99, 'answer': 'Upper_Level_Float_Switch = WET'}
# Upper_Level_Float_Switch = WET
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Upper_Level_Float_Switch,WET
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9362202286720276, 'start': 111, 'end': 141, 'answer': 'Low_Level_Float_Switch_1 = DRY'}
# Low_Level_Float_Switch_1 = DRY
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Low_Level_Float_Switch_1,DRY
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.953607976436615, 'start': 153, 'end': 183, 'answer': 'Upper_Level_Float_Switch = WET'}
# Upper_Level_Float_Switch = WET
# 2
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Upper_Level_Float_Switch,WET
#
# data inside for loop
# [' what is C4?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9471179246902466, 'start': 195, 'end': 225, 'answer': 'Low_Level_Float_Switch_2 = DRY'}
# Low_Level_Float_Switch_2 = DRY
# 2
# Inference:
# Question:  what is C4?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Low_Level_Float_Switch_2,DRY
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:\nC1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.\nC2: (VI_Air_Ground_Status = GROUND)']
# model Predictions
# {'score': 0.9033588767051697, 'start': 35, 'end': 65, 'answer': 'VI_Delayed_In_Air = NOT IN AIR'}
# VI_Delayed_In_Air = NOT IN AIR
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:
# C1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.
# C2: (VI_Air_Ground_Status = GROUND)
# model answer: VI_Delayed_In_Air,NOT IN AIR
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:\nC1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.\nC2: (VI_Air_Ground_Status = GROUND)']
# model Predictions
# {'score': 0.6105570793151855, 'start': 118, 'end': 144, 'answer': 'VI_Air_Ground_Status = AIR'}
# VI_Air_Ground_Status = AIR
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:
# C1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.
# C2: (VI_Air_Ground_Status = GROUND)
# model answer: VI_Air_Ground_Status,AIR
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:\nC1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.\nC2: (VI_Air_Ground_Status = GROUND)']
# model Predictions
# {'score': 0.9465562105178833, 'start': 198, 'end': 227, 'answer': 'VI_Air_Ground_Status = GROUND'}
# VI_Air_Ground_Status = GROUND
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set VI_Delayed_In_Air = NOT IN AIR, if any of the following conditions are TRUE:
# C1:  (VI_Air_Ground_Status = AIR) for less than TIMER_DELAYED_START_IN_AIR time.
# C2: (VI_Air_Ground_Status = GROUND)
# model answer: VI_Air_Ground_Status,GROUND
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR \nC2: (Air_Ground_2 = IN AIR))']
# model Predictions
# {'score': 0.8049453496932983, 'start': 35, 'end': 61, 'answer': 'VI_Air_Ground_Status = AIR'}
# VI_Air_Ground_Status = AIR
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR
# C2: (Air_Ground_2 = IN AIR))
# model answer: VI_Air_Ground_Status,AIR
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR \nC2: (Air_Ground_2 = IN AIR))']
# model Predictions
# {'score': 0.9411266446113586, 'start': 72, 'end': 100, 'answer': 'Air_Ground_1 = NOT ON GROUND'}
# Air_Ground_1 = NOT ON GROUND
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR
# C2: (Air_Ground_2 = IN AIR))
# model answer: Air_Ground_1,NOT ON GROUND
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR \nC2: (Air_Ground_2 = IN AIR))']
# model Predictions
# {'score': 0.9626983404159546, 'start': 111, 'end': 132, 'answer': 'Air_Ground_2 = IN AIR'}
# Air_Ground_2 = IN AIR
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set VI_Air_Ground_Status = AIR, if C1: ((Air_Ground_1 = NOT ON GROUND) OR
# C2: (Air_Ground_2 = IN AIR))
# model answer: Air_Ground_2,IN AIR
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED) ']
# model Predictions
# {'score': 0.013876720331609249, 'start': 35, 'end': 71, 'answer': 'Bleed_Air_Valve_Enable_Cmd = ENABLED'}
# Bleed_Air_Valve_Enable_Cmd = ENABLED
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)
# model answer: Bleed_Air_Valve_Enable_Cmd,ENABLED
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED) ']
# model Predictions
# {'score': 0.9370748996734619, 'start': 121, 'end': 145, 'answer': 'AFCU_State = MAINTENANCE'}
# AFCU_State = MAINTENANCE
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)
# model answer: AFCU_State,MAINTENANCE
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED) ']
# model Predictions
# {'score': 0.9362200498580933, 'start': 152, 'end': 191, 'answer': 'Bleed_Air_Valve_Cmd_Override = OVERRIDE'}
# Bleed_Air_Valve_Cmd_Override = OVERRIDE
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)
# model answer: Bleed_Air_Valve_Cmd_Override,OVERRIDE
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED) ']
# model Predictions
# {'score': 0.0032529307063668966, 'start': 199, 'end': 232, 'answer': 'Maint_Bleed_Air_Valve_Enabled_Cmd'}
# Maint_Bleed_Air_Valve_Enabled_Cmd
# 1
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = ENABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = ENABLED)
# model answer: Maint_Bleed_Air_Valve_Enabled_Cmd
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED) ']
# model Predictions
# {'score': 0.9446943402290344, 'start': 35, 'end': 72, 'answer': 'Bleed_Air_Valve_Enable_Cmd = DISABLED'}
# Bleed_Air_Valve_Enable_Cmd = DISABLED
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)
# model answer: Bleed_Air_Valve_Enable_Cmd,DISABLED
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED) ']
# model Predictions
# {'score': 0.9404690861701965, 'start': 122, 'end': 146, 'answer': 'AFCU_State = MAINTENANCE'}
# AFCU_State = MAINTENANCE
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)
# model answer: AFCU_State,MAINTENANCE
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED) ']
# model Predictions
# {'score': 0.941632091999054, 'start': 153, 'end': 192, 'answer': 'Bleed_Air_Valve_Cmd_Override = OVERRIDE'}
# Bleed_Air_Valve_Cmd_Override = OVERRIDE
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)
# model answer: Bleed_Air_Valve_Cmd_Override,OVERRIDE
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE \nC1: (AFCU_State = MAINTENANCE)\nC2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE) \nC3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED) ']
# model Predictions
# {'score': 0.006158359348773956, 'start': 200, 'end': 233, 'answer': 'Maint_Bleed_Air_Valve_Enabled_Cmd'}
# Maint_Bleed_Air_Valve_Enabled_Cmd
# 1
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set Bleed_Air_Valve_Enable_Cmd = DISABLED,  if all the following conditions are TRUE
# C1: (AFCU_State = MAINTENANCE)
# C2: (Bleed_Air_Valve_Cmd_Override = OVERRIDE)
# C3: (Maint_Bleed_Air_Valve_Enabled_Cmd = DISABLED)
# model answer: Maint_Bleed_Air_Valve_Enabled_Cmd
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9531180262565613, 'start': 35, 'end': 58, 'answer': 'FD_LLFS_Rev_Snsr = TRUE'}
# FD_LLFS_Rev_Snsr = TRUE
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: FD_LLFS_Rev_Snsr,TRUE
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9402456879615784, 'start': 69, 'end': 99, 'answer': 'Upper_Level_Float_Switch = WET'}
# Upper_Level_Float_Switch = WET
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Upper_Level_Float_Switch,WET
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9362202286720276, 'start': 111, 'end': 141, 'answer': 'Low_Level_Float_Switch_1 = DRY'}
# Low_Level_Float_Switch_1 = DRY
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Low_Level_Float_Switch_1,DRY
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.953607976436615, 'start': 153, 'end': 183, 'answer': 'Upper_Level_Float_Switch = WET'}
# Upper_Level_Float_Switch = WET
# 2
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Upper_Level_Float_Switch,WET
#
# data inside for loop
# [' what is C4?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9471179246902466, 'start': 195, 'end': 225, 'answer': 'Low_Level_Float_Switch_2 = DRY'}
# Low_Level_Float_Switch_2 = DRY
# 2
# Inference:
# Question:  what is C4?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Low_Level_Float_Switch_2,DRY
#
# data inside for loop
# ['what shall be set?', 'The Operational Software in microcontroller B shall set \nC1: HB_Mon_B = HIGH, If HB_Mon_A = LOW\nC2: HB_Mon_B = LOW, If HB_Mon_A = HIGH']
# model Predictions
# {'score': 0.4042980372905731, 'start': 61, 'end': 76, 'answer': 'HB_Mon_B = HIGH'}
# HB_Mon_B = HIGH
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software in microcontroller B shall set
# C1: HB_Mon_B = HIGH, If HB_Mon_A = LOW
# C2: HB_Mon_B = LOW, If HB_Mon_A = HIGH
# model answer: HB_Mon_B,HIGH
#
# data inside for loop
# [' What is C1?', 'The Operational Software in microcontroller B shall set \nC1: HB_Mon_B = HIGH, If HB_Mon_A = LOW\nC2: HB_Mon_B = LOW, If HB_Mon_A = HIGH']
# model Predictions
# {'score': 0.9022924900054932, 'start': 61, 'end': 76, 'answer': 'HB_Mon_B = HIGH'}
# HB_Mon_B = HIGH
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software in microcontroller B shall set
# C1: HB_Mon_B = HIGH, If HB_Mon_A = LOW
# C2: HB_Mon_B = LOW, If HB_Mon_A = HIGH
# model answer: HB_Mon_B,HIGH
#
# data inside for loop
# [' what is C2?', 'The Operational Software in microcontroller B shall set \nC1: HB_Mon_B = HIGH, If HB_Mon_A = LOW\nC2: HB_Mon_B = LOW, If HB_Mon_A = HIGH']
# model Predictions
# {'score': 0.9788903594017029, 'start': 100, 'end': 114, 'answer': 'HB_Mon_B = LOW'}
# HB_Mon_B = LOW
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software in microcontroller B shall set
# C1: HB_Mon_B = HIGH, If HB_Mon_A = LOW
# C2: HB_Mon_B = LOW, If HB_Mon_A = HIGH
# model answer: HB_Mon_B,LOW
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND\nC1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR\nC2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))\nelse set to \nC3: FD_CTFS_Stop_Mismatch = FALSE']
# model Predictions
# {'score': 0.9289619326591492, 'start': 35, 'end': 63, 'answer': 'FD_CTFS_Stop_Mismatch = TRUE'}
# FD_CTFS_Stop_Mismatch = TRUE
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND
# C1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR
# C2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))
# else set to
# C3: FD_CTFS_Stop_Mismatch = FALSE
# model answer: FD_CTFS_Stop_Mismatch,TRUE
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND\nC1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR\nC2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))\nelse set to \nC3: FD_CTFS_Stop_Mismatch = FALSE']
# model Predictions
# {'score': 0.5583967566490173, 'start': 105, 'end': 122, 'answer': 'CTFS_Stop_A = DRY'}
# CTFS_Stop_A = DRY
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND
# C1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR
# C2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))
# else set to
# C3: FD_CTFS_Stop_Mismatch = FALSE
# model answer: CTFS_Stop_A,DRY
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND\nC1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR\nC2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))\nelse set to \nC3: FD_CTFS_Stop_Mismatch = FALSE']
# model Predictions
# {'score': 0.6339369416236877, 'start': 158, 'end': 175, 'answer': 'CTFS_Stop_A = WET'}
# CTFS_Stop_A = WET
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND
# C1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR
# C2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))
# else set to
# C3: FD_CTFS_Stop_Mismatch = FALSE
# model answer: CTFS_Stop_A,WET
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND\nC1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR\nC2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))\nelse set to \nC3: FD_CTFS_Stop_Mismatch = FALSE']
# model Predictions
# {'score': 0.9842002391815186, 'start': 219, 'end': 248, 'answer': 'FD_CTFS_Stop_Mismatch = FALSE'}
# FD_CTFS_Stop_Mismatch = FALSE
# 2
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set FD_CTFS_Stop_Mismatch = TRUE, if (FD_XCDL_Bus_Fail = FALSE) AND
# C1: ((CTFS_Stop_A = DRY) AND (CTFS_Stop_B = WET)) OR
# C2: ((CTFS_Stop_A = WET) AND (CTFS_Stop_B = DRY))
# else set to
# C3: FD_CTFS_Stop_Mismatch = FALSE
# model answer: FD_CTFS_Stop_Mismatch,FALSE
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))']
# model Predictions
# {'score': 0.9709221720695496, 'start': 35, 'end': 61, 'answer': 'FD_CTFS_Rev_Snsr_X = FALSE'}
# FD_CTFS_Rev_Snsr_X = FALSE
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))
# model answer: FD_CTFS_Rev_Snsr_X,FALSE
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))']
# model Predictions
# {'score': 0.9629451036453247, 'start': 72, 'end': 89, 'answer': 'CTFS_Stop_X = DRY'}
# CTFS_Stop_X = DRY
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))
# model answer: CTFS_Stop_X,DRY
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))']
# model Predictions
# {'score': 0.747702956199646, 'start': 100, 'end': 117, 'answer': 'CTFS_Stop_X = WET'}
# CTFS_Stop_X = WET
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))
# model answer: CTFS_Stop_X,WET
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))']
# model Predictions
# {'score': 6.9169705056992825e-06, 'start': 100, 'end': 117, 'answer': 'CTFS_Stop_X = WET'}
# CTFS_Stop_X = WET
# 2
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))
# model answer: CTFS_Stop_X,WET
#
# data inside for loop
# [' what is C4?', 'The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if\nC1: ((CTFS_Stop_X = DRY) OR\nC2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))']
# model Predictions
# {'score': 2.5357294362038374e-06, 'start': 100, 'end': 117, 'answer': 'CTFS_Stop_X = WET'}
# CTFS_Stop_X = WET
# 2
# Inference:
# Question:  what is C4?
# Context: The Operational Software shall set FD_CTFS_Rev_Snsr_X = FALSE, if
# C1: ((CTFS_Stop_X = DRY) OR
# C2: ((CTFS_Stop_X = WET) AND (CTFS_Start_X = WET))
# model answer: CTFS_Stop_X,WET
#
# data inside for loop
# ['what shall be set?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9531180262565613, 'start': 35, 'end': 58, 'answer': 'FD_LLFS_Rev_Snsr = TRUE'}
# FD_LLFS_Rev_Snsr = TRUE
# 2
# Inference:
# Question: what shall be set?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: FD_LLFS_Rev_Snsr,TRUE
#
# data inside for loop
# [' What is C1?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9402456879615784, 'start': 69, 'end': 99, 'answer': 'Upper_Level_Float_Switch = WET'}
# Upper_Level_Float_Switch = WET
# 2
# Inference:
# Question:  What is C1?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Upper_Level_Float_Switch,WET
#
# data inside for loop
# [' what is C2?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9362202286720276, 'start': 111, 'end': 141, 'answer': 'Low_Level_Float_Switch_1 = DRY'}
# Low_Level_Float_Switch_1 = DRY
# 2
# Inference:
# Question:  what is C2?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Low_Level_Float_Switch_1,DRY
#
# data inside for loop
# [' what is  C3?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.953607976436615, 'start': 153, 'end': 183, 'answer': 'Upper_Level_Float_Switch = WET'}
# Upper_Level_Float_Switch = WET
# 2
# Inference:
# Question:  what is  C3?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Upper_Level_Float_Switch,WET
#
# data inside for loop
# [' what is C4?', 'The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if\nC1: ((Upper_Level_Float_Switch = WET) AND \nC2: (Low_Level_Float_Switch_1 = DRY)) OR\nC3: ((Upper_Level_Float_Switch = WET) AND \nC4: (Low_Level_Float_Switch_2 = DRY))']
# model Predictions
# {'score': 0.9471179246902466, 'start': 195, 'end': 225, 'answer': 'Low_Level_Float_Switch_2 = DRY'}
# Low_Level_Float_Switch_2 = DRY
# 2
# Inference:
# Question:  what is C4?
# Context: The Operational Software shall set FD_LLFS_Rev_Snsr = TRUE, if
# C1: ((Upper_Level_Float_Switch = WET) AND
# C2: (Low_Level_Float_Switch_1 = DRY)) OR
# C3: ((Upper_Level_Float_Switch = WET) AND
# C4: (Low_Level_Float_Switch_2 = DRY))
# model answer: Low_Level_Float_Switch_2,DRY
#
# 19

# %%
for srno in range(2,count+1):
    copytoExcel(r"../new/compressed/final2.xlsx", srno, 6 ,AnsDictionary[srno])
    copytoExcel(r"../new/compressed/final2.xlsx", srno, 5 ,AnsDictionary2[srno])
